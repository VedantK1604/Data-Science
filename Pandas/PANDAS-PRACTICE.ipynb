# %%
import numpy as np
import pandas as pd

# %%
index = ['i', 'ii', 'iii', 'iiii', 'iiiii', 'iiiiii']
ls = ['vedant', 'girish', 'harsh', 'sujal', 'bhushan', 'shruti']
pd.Series(ls,index=index)
# Out:
# i          vedant
# ii         girish
# iii         harsh
# iiii        sujal
# iiiii     bhushan
# iiiiii     shruti
# dtype: object

# %%
dic = {
    'v = ': 'vedant',
    's = ': 'shruti',
    'b = ': 'bhushan'
}
friends = pd.Series(dic, name='vedant friends')

# %%
friends
# Out:
# v =      vedant
# s =      shruti
# b =     bhushan
# Name: vedant friends, dtype: object

# %%
friends.size
# Out:
# 3

# %%
friends.index
# Out:
# Index(['v = ', 's = ', 'b = '], dtype='object')

# %%
df = pd.read_csv('penguins.csv')

# %%
df.head()
# Out:
#    id species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   0  Adelie  Torgersen            39.1           18.7              181.0
# 1   1  Adelie  Torgersen            39.5           17.4              186.0
# 2   2  Adelie  Torgersen            40.3           18.0              195.0
# 3   3  Adelie  Torgersen             NaN            NaN                NaN
# 4   4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
new_df = df['flipper_length_mm']

# %%
 new_df.tail()
# Out:
# 339    207.0
# 340    202.0
# 341    193.0
# 342    210.0
# 343    198.0
# Name: flipper_length_mm, dtype: float64

# %%
new_df.sample(5)
# Out:
# 191    208.0
# 269    222.0
# 192    208.0
# 306    187.0
# 150    187.0
# Name: flipper_length_mm, dtype: float64

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df.count()
# Out:
# id                   344
# species              344
# island               344
# bill_length_mm       342
# bill_depth_mm        342
# flipper_length_mm    342
# body_mass_g          342
# sex                  333
# year                 344
# dtype: int64

# %%
df['flipper_length_mm'].sum()
# Out:
# 68713.0

# %%
df.describe()
# Out:
#                id  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   171.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      0.000000       32.100000      13.100000         172.000000
# 25%     85.750000       39.225000      15.600000         190.000000
# 50%    171.500000       44.450000      17.300000         197.000000
# 75%    257.250000       48.500000      18.700000         213.000000
# max    343.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
df[df['flipper_length_mm'] > 200]
# Out:
#       id    species     island  bill_length_mm  bill_depth_mm  \
# 90    90     Adelie      Dream            35.7           18.0
# 91    91     Adelie      Dream            41.1           18.1
# 95    95     Adelie      Dream            40.8           18.9
# 101  101     Adelie     Biscoe            41.0           20.0
# 123  123     Adelie  Torgersen            41.4           18.5
# ..   ...        ...        ...             ...            ...
# 334  334  Chinstrap      Dream            50.2           18.8
# 336  336  Chinstrap      Dream            51.9           19.5
# 339  339  Chinstrap      Dream            55.8           19.8
# 340  340  Chinstrap      Dream            43.5           18.1
# 342  342  Chinstrap      Dream            50.8           19.0
#
#      flipper_length_mm  body_mass_g     sex  year
# 90               202.0       3550.0  female  2008
# 91               205.0       4300.0    male  2008
# 95               208.0       4300.0    male  2008
# ...

# %%
df['flipper_length_mm'].plot()
# Out:
# <Axes: >

# %%
df['flipper_length_mm'].value_counts().head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#    id species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   0  Adelie  Torgersen            39.1           18.7              181.0
# 1   1  Adelie  Torgersen            39.5           17.4              186.0
# 2   2  Adelie  Torgersen            40.3           18.0              195.0
# 3   3  Adelie  Torgersen             NaN            NaN                NaN
# 4   4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
df['body_mass_g_rank'] = df['body_mass_g'].rank(ascending=False)

# %%
df.sort_values('body_mass_g_rank')
# Out:
#       id    species     island  bill_length_mm  bill_depth_mm  \
# 169  169     Gentoo     Biscoe            49.2           15.2
# 185  185     Gentoo     Biscoe            59.6           17.0
# 229  229     Gentoo     Biscoe            51.1           16.3
# 269  269     Gentoo     Biscoe            48.8           16.2
# 263  263     Gentoo     Biscoe            49.8           15.9
# ..   ...        ...        ...             ...            ...
# 64    64     Adelie     Biscoe            36.4           17.1
# 58    58     Adelie     Biscoe            36.5           16.6
# 314  314  Chinstrap      Dream            46.9           16.6
# 3      3     Adelie  Torgersen             NaN            NaN
# 271  271     Gentoo     Biscoe             NaN            NaN
#
#      flipper_length_mm  body_mass_g     sex  year  body_mass_g_rank
# 169              221.0       6300.0    male  2007               1.0
# 185              230.0       6050.0    male  2007               2.0
# ...

# %%
df.head()
# Out:
#    id species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   0  Adelie  Torgersen            39.1           18.7              181.0
# 1   1  Adelie  Torgersen            39.5           17.4              186.0
# 2   2  Adelie  Torgersen            40.3           18.0              195.0
# 3   3  Adelie  Torgersen             NaN            NaN                NaN
# 4   4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year  body_mass_g_rank
# 0       3750.0    male  2007             220.0
# 1       3800.0  female  2007             207.5
# 2       3250.0  female  2007             312.0
# 3          NaN     NaN  2007               NaN
# 4       3450.0  female  2007             278.5

# %%
df.reset_index().set_index('body_mass_g_rank')
# Out:
#                   index   id    species     island  bill_length_mm  \
# body_mass_g_rank
# 220.0                 0    0     Adelie  Torgersen            39.1
# 207.5                 1    1     Adelie  Torgersen            39.5
# 312.0                 2    2     Adelie  Torgersen            40.3
# NaN                   3    3     Adelie  Torgersen             NaN
# 278.5                 4    4     Adelie  Torgersen            36.7
# ...                 ...  ...        ...        ...             ...
# 175.0               339  339  Chinstrap      Dream            55.8
# 288.5               340  340  Chinstrap      Dream            43.5
# 215.5               341  341  Chinstrap      Dream            49.6
# 163.0               342  342  Chinstrap      Dream            50.8
# 215.5               343  343  Chinstrap      Dream            50.2
#
#                   bill_depth_mm  flipper_length_mm  body_mass_g     sex  year
# body_mass_g_rank
# ...
